# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import numpy as np
import pandas as pd

# %% [markdown]
# # Challenge 1 - Independent Sample T-tests
#
# In this challenge, we will be using the Pokemon dataset. Before applying statistical methods to this data, let's first examine the data.
#
# To load the data, run the code below.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2066c84d-3b08-4117-a33d-022afbe54407" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2066c84d-3b08-4117-a33d-022afbe54407">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Run this code:

import io
pokemon = pd.read_csv(io.BytesIO(uploaded['Pokemon.csv']))

# Dataset is now stored in a Pandas Dataframe

# %% [markdown]
# Let's start off by looking at the `head` function in the cell below.

# %%
# Your code here:

pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# The first thing we would like to do is compare the legendary Pokemon to the regular Pokemon. To do this, we should examine the data further. What is the count of legendary vs. non legendary Pokemons?

# %%
# Your code here:
leg=pokemon[pokemon['Legendary'] == True]
non_leg=pokemon[pokemon['Legendary'] == False]
print('legend count: ', len(leg),'; non-legend count: ',len(non_leg))
# Out:
# legend count:  65 ; non-legend count:  735

# %% [markdown]
# Compute the mean and standard deviation of the total points for both legendary and non-legendary Pokemon.

# %%
# Your code here:
l_m=leg['Total'].mean()
l_std=leg['Total'].std()

n_l_m=non_leg['Total'].mean()
n_l_std=non_leg['Total'].std()

print('legend mean & std: ', l_m, ' & ', l_std,';\nnon-legend mean & std: ', n_l_m, ' & ', n_l_std,)
# Out:
# legend mean & std:  637.3846153846154  &  60.93738905315344 ;
# non-legend mean & std:  417.21360544217686  &  106.76041745713005

# %% [markdown]
# The computation of the mean might give us a clue regarding how the statistical test may turn out; However, it certainly does not prove whether there is a significant difference between the two groups.
#
# In the cell below, use the `ttest_ind` function in `scipy.stats` to compare the the total points for legendary and non-legendary Pokemon. Since we do not have any information about the population, assume the variances are not equal.

# %%
# Your code here:
from scipy import stats
a=stats.ttest_ind(leg['Total'], non_leg['Total'], equal_var=False)
a.pvalue
# Out:
# 9.357954335957446e-47

# %% [markdown]
# What do you conclude from this test? Write your conclusions below.

# %%
# Your conclusions here:
# Null Hypothesis, those 2 samples are the same 
# since p-value is below 0.05
# we can confidently declare the null-hypothesis is rejected and the difference is significant.

# %% [markdown]
# How about we try to compare the different types of pokemon? In the cell below, list the types of Pokemon from column `Type 1` and the count of each type.

# %%
# Your code here:
type_1 = pokemon['Type 1'].unique()

pokemon['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# Since water is the largest group of Pokemon, compare the mean and standard deviation of water Pokemon to all other Pokemon.

# %%
# Your code here:
water = pokemon[pokemon['Type 1']=='Water']
w_m=water['Total'].mean()
w_std=water['Total'].std()

not_water = pokemon[pokemon['Type 1']!='Water']
n_w_m=not_water['Total'].mean()
n_w_std=not_water['Total'].std()

print('water mean & std: ', w_m, ' & ', w_std,';\nnot-water mean & std: ', n_w_m, ' & ', n_w_std,)
# Out:
# water mean & std:  430.45535714285717  &  113.1882660643146 ;
# not-water mean & std:  435.85901162790697  &  121.0916823020807

# %% [markdown]
# Perform a hypothesis test comparing the mean of total points for water Pokemon to all non-water Pokemon. Assume the variances are equal.

# %%
# Your code here:
a=stats.ttest_ind(water['Total'], not_water['Total'], equal_var=True)
a.pvalue
# Out:
# 0.6587140317488793

# %% [markdown]
# Write your conclusion below.

# %%
# Your conclusions here:
# Null Hypothesis, those 2 samples are the same 
# since p-value is above 0.05
# we can confidently declare the null-hypothesis is accepted and those two samples groups have no significance difference in the total score

# %% [markdown]
# # Challenge 2 - Matched Pairs Test
#
# In this challenge we will compare dependent samples of data describing our Pokemon. Our goal is to see whether there is a significant difference between each Pokemon's defense and attack scores. Our hypothesis is that the defense and attack scores are equal. In the cell below, import the `ttest_rel` function from `scipy.stats` and compare the two columns to see if there is a statistically significant difference between them.

# %%
# Your code here:
from scipy.stats import ttest_rel
ttest_rel(pokemon['Attack'], pokemon['Defense'])
# Out:
# Ttest_relResult(statistic=4.325566393330478, pvalue=1.7140303479358558e-05)

# %% [markdown]
# Describe the results of the test in the cell below.

# %%
# Your conclusions here:
# Null Hypothesis: those 2 cols are the same 
# since p-value is below 0.05
# we can confidently declare the null-hypothesis is rejected and the difference is significant between defense and attack scores columns.

# %% [markdown]
# We are also curious about whether therer is a significant difference between the mean of special defense and the mean of special attack. Perform the hypothesis test in the cell below.

# %%
# Your code here:
stats.ttest_rel(pokemon['Sp. Atk'], pokemon['Sp. Def'])
# Out:
# Ttest_relResult(statistic=0.853986188453353, pvalue=0.3933685997548122)

# %% [markdown]
# Describe the results of the test in the cell below.

# %%
# Your conclusions here:
# Null Hypothesis: mean difference between two samples are the same.
# since p-value is above 0.05
# we can confidently declare the null-hypothesis is accepted, therer is no significant difference between the mean of special defense and the mean of special attack

# %% [markdown]
# As you may recall, a two sample matched pairs test can also be expressed as a one sample test of the difference between the two dependent columns.
#
# Import the `ttest_1samp` function and perform a one sample t-test of the difference between defense and attack. Test the hypothesis that the difference between the means is zero. Confirm that the results of the test are the same.

# %%
# Your code here:
from scipy.stats import ttest_1samp
diff=pokemon['Attack']-pokemon['Defense']
ttest_1samp(diff, 0) 

#same result of pvalue with Challenge 2, task 1
# Out:
# Ttest_1sampResult(statistic=4.325566393330478, pvalue=1.7140303479358558e-05)

# %%
# Null Hypothesis: mean difference between two samples is equal to 0.
# since p-value is below 0.05
# we can confidently declare the null-hypothesis is rejected and the difference is significant between defense and attack scores columns.

# %% [markdown]
# # Bonus Challenge - The Chi-Square Test
#
# The Chi-Square test is used to determine whether there is a statistically significant difference in frequencies. In other words, we are testing whether there is a relationship between categorical variables or rather when the variables are independent. This test is an alternative to Fisher's exact test and is used in scenarios where sample sizes are larger. However, with a large enough sample size, both tests produce similar results. Read more about the Chi Squared test [here](https://en.wikipedia.org/wiki/Chi-squared_test).
#
# In the cell below, create a contingency table using `pd.crosstab` comparing whether a Pokemon is legenadary or not and whether the Type 1 of a Pokemon is water or not.

# %%
# Your code here:
pokemon['Water']= np.where(pokemon['Type 1']== 'Water', 'Water', 'Not-Water')

len_water = pd.crosstab(pokemon['Legendary'],pokemon['Water'])
len_water
# Out:
# Water      Not-Water  Water
# Legendary
# False            627    108
# True              61      4

# %% [markdown]
# Perform a chi-squared test using the `chi2_contingency` function in `scipy.stats`. You can read the documentation of the function [here](https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.chi2_contingency.html).

# %%
# Your code here:
# Null hypothesis: no relationship exists on the 2 categorical variables in the population; they are independent
from scipy.stats import chi2_contingency
chi2, p, dof, ex = chi2_contingency(len_water, correction=False)
p
# Out:
# 0.0571762700873503

# %% [markdown]
# Based on a 95% confidence, should we reject the null hypothesis?

# %%
# Your answer here:
# since p-value is more than 0.05
# we can declare the null-hypothesis is accepted, those 2 categorical variables are independent
