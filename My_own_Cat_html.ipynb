# %%
import requests

url = 'C:\Users\borys\AppData\Roaming\Microsoft\Windows\Network Shortcuts\htmlwebsite.ipynb'
html = requests.get(url).content
html
# Out:
#   File "<ipython-input-1-977aff1edab8>", line 3
#     url = 'C:\Users\borys\AppData\Roaming\Microsoft\Windows\Network Shortcuts\htmlwebsite.ipynb'
#          ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
