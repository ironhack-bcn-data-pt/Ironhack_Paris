# %% [markdown]
# # StackAPI
#
# #### Import the necessary libraries here:

# %%
# your code here

from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
questions = SITE.fetch('questions', fromdate=1457136000, todate=1457222400, min=20, tagged='python', sort='votes')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-e44649dde524> in <module>
#       1 # your code here
#       2
# ----> 3 from stackapi import StackAPI
#       4 SITE = StackAPI('stackoverflow')
#       5 questions = SITE.fetch('questions', fromdate=1457136000, todate=1457222400, min=20, tagged='python', sort='votes')
#
# ModuleNotFoundError: No module named 'stackapi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# #### Question 1: Find the questions and answers of last month.

# %%
# your code here
questions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-171f155c022e> in <module>
#       1 # your code here
# ----> 2 questions
#
# NameError: name 'questions' is not defined

# %% [markdown]
# #### Question 2: Find the most voted question today with at least a score of 5 and tagged with 'python'.

# %%
# your code here

from stackapi import StackAPI
SITE = StackAPI('stackoverflow')
answers = SITE.fetch('answers', fromdate=1457136000, todate=1457222400, min=20, tagged='python', sort='votes')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-a161305a1d91> in <module>
#       1 # your code here
#       2
# ----> 3 from stackapi import StackAPI
#       4 SITE = StackAPI('stackoverflow')
#       5 answers = SITE.fetch('answers', fromdate=1457136000, todate=1457222400, min=20, tagged='python', sort='votes')
#
# ModuleNotFoundError: No module named 'stackapi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# #### Question 3: Find the answers with id 6784 and 6473.

# %%
# your code here

SITE = StackAPI('stackoverflow')
badges = SITE.fetch('badges', ids=[6784, 6473])
badges
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-add7da963e5a> in <module>
#       1 # your code here
#       2
# ----> 3 SITE = StackAPI('stackoverflow')
#       4 badges = SITE.fetch('badges', ids=[6784, 6473])
#       5 badges
#
# NameError: name 'StackAPI' is not defined
